# %% [markdown]
# imagenes con numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pwd
# Out:
# 'c:\\Users\\ASUS\\Desktop\\MAC\\proyecto'

# %%
cd c:\\Users\\ASUS\\Desktop\\MAC\\proyecto
# Out:
# c:\Users\ASUS\Desktop\MAC\proyecto

# %%
imagen = Image.open('perro.jpg')

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1280 at 0x23A97B831C0>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (1920, 1280)

# %%
array_imagen = np.asarray(imagen) # Convertir imagen a array

# %%
array_imagen
# Out:
# array([[[237, 234, 217],
#         [240, 237, 220],
#         [244, 241, 224],
#         ...,
#         [230, 229, 199],
#         [229, 228, 198],
#         [227, 226, 196]],
#
#        [[239, 236, 219],
#         [241, 238, 221],
#         [243, 240, 223],
#         ...,
#         [229, 228, 198],
#         [229, 228, 198],
#         [229, 228, 198]],
#
#        [[240, 237, 220],
#         [241, 238, 221],
#         [242, 239, 222],
#         ...,
#         [228, 227, 197],
#         [229, 228, 198],
#         [230, 229, 198]],
#
#        ...,
#
#        [[ 46,  27,  20],
#         [ 52,  33,  26],
#         [ 55,  35,  28],
#         ...,
#         [ 55,  34,  17],
#         [ 56,  35,  18],
#         [ 58,  35,  19]],
#
#        [[ 55,  36,  29],
#         [ 54,  35,  28],
#         [ 50,  31,  24],
#         ...,
#         [ 58,  35,  19],
#         [ 62,  36,  21],
#         [ 64,  38,  23]],
#
#        [[ 50,  31,  24],
#         [ 52,  33,  26],
#         [ 51,  32,  25],
# ...

# %%
plt.imshow(array_imagen)# Mostrar imagen

# %%
array_imagen.shape# Dimensiones de la imagen
# Out:
# (1280, 1920, 3)

# %%
array_imagen[:,:,1] # Obtener el canal verde
# Out:
# array([[237, 240, 244, ..., 230, 229, 227],
#        [239, 241, 243, ..., 229, 229, 229],
#        [240, 241, 242, ..., 228, 229, 230],
#        ...,
#        [ 46,  52,  55, ...,  55,  56,  58],
#        [ 55,  54,  50, ...,  58,  62,  64],
#        [ 50,  52,  51, ...,  62,  67,  73]], dtype=uint8)

# %%
array_imagen
# Out:
# array([[[237, 234, 217],
#         [240, 237, 220],
#         [244, 241, 224],
#         ...,
#         [230, 229, 199],
#         [229, 228, 198],
#         [227, 226, 196]],
#
#        [[239, 236, 219],
#         [241, 238, 221],
#         [243, 240, 223],
#         ...,
#         [229, 228, 198],
#         [229, 228, 198],
#         [229, 228, 198]],
#
#        [[240, 237, 220],
#         [241, 238, 221],
#         [242, 239, 222],
#         ...,
#         [228, 227, 197],
#         [229, 228, 198],
#         [230, 229, 198]],
#
#        ...,
#
#        [[ 46,  27,  20],
#         [ 52,  33,  26],
#         [ 55,  35,  28],
#         ...,
#         [ 55,  34,  17],
#         [ 56,  35,  18],
#         [ 58,  35,  19]],
#
#        [[ 55,  36,  29],
#         [ 54,  35,  28],
#         [ 50,  31,  24],
#         ...,
#         [ 58,  35,  19],
#         [ 62,  36,  21],
#         [ 64,  38,  23]],
#
#        [[ 50,  31,  24],
#         [ 52,  33,  26],
#         [ 51,  32,  25],
# ...
