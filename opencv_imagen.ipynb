# %%
import numpy as np #import numpy as np
import matplotlib.pyplot as plt # importamos la libreria matplotlib
import cv2 # impotamos |cv2|

# %%
cd C:\Users\ASUS\Desktop\MAC\luis21
# Out:
# c:\Users\ASUS\Desktop\MAC\luis21

# %%
imagen = cv2.imread('perro.jpg') # leemos la imagen

# %%
type(imagen) # tipo de dato de la imagen
# Out:
# numpy.ndarray

# %%
imagen.shape # dimensiones de la imagen
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(imagen) # mostramos la imagen

# %%
#opencv --> BGR
#matplotlib --> RGB

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB) # convertimos la imagen a RGB
plt.imshow(imagen) # mostramos la imagen

# %%
plt.imshow(imagen_gris, cmap="gray")
